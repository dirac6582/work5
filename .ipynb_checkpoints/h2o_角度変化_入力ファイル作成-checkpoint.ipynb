# %% [markdown]
# # ボンド角度が変化する孤立水分子の計算
#
# ## 2022/2/15
#
# ## 角度を変化させ，対応するQEのinputファイルを自動生成する．
#
#
# ## 長さ変化にも変数logを用いることで対応した．

# %%
import numpy as np

# %%
# ファイルを読み込み．
#zahixyou=np.loadtxt("h2o_mol2.pos")
#print(zahixyou)
#print(zahixyou[44])

# %%
#===============================
# 基本的な定数
#===============================
#
# 格子定数(in bohr unit)
CELL_PARAM=10

# %%
#O，H1，H2はいずれも3次元の座標
def make_file(O,H1,H2):
    lines= [
    "&control", 
    "      calculation = 'scf'", 
    "      prefix = 'h2o_bec'", 
    "      pseudo_dir = '/home/amano/src/qe-6.4.1/pseudo/'", 
    "      outdir           = './work/'", 
    " ",    
    "/", 
    "&system", 
    "      ibrav=1",
    "      celldm(1) = {0}".format(CELL_PARAM), 
    "      nat=3, ntyp=2,", 
    "      ecutwfc=70.0", 
    "      nosym =.TRUE.", 
    "/", 
    "&electrons", 
    "      conv_thr=1e-8", 
    "/", 
    "&ions", 
    "/", 
    "ATOMIC_SPECIES", 
    "H   1.00784 H.pbe-rrkjus_psl.1.0.0.UPF", 
    "O  15.999 O.pbe-n-rrkjus_psl.1.0.0.UPF", 
    " ",
    " " ,  
    "ATOMIC_POSITIONS (angstrom)", 
    " O {0} {1} {2}".format(O[0], O[1], O[2]), 
    " H {0} {1} {2}".format(H1[0], H1[1], H1[2]), 
    " H {0} {1} {2}".format(H2[0], H2[1], H2[2]), 
    " " , 
    "K_POINTS (automatic)", 
    " 1 1 1 0 0 0", 
    ]
    #出力ファイル名
    output="h2o_bec.pw.in"
    #ファイルの保存
    with open(output, mode='w') as f:
        f.write('\n'.join(lines))

# %%
#phファイルの方
def make_phfile():
    lines=[
    "h2o phonon",
    "&inputph",
    "     tr2_ph = 1.0d-14," ,
    "     prefix = 'h2o_bec'" ,
    "     outdir = './work/'"  ,
    "     trans  = .true.", 
    "     zue    = .true.", 
    "     epsil  = .true.", 
    "   asr      = .true.",    
    "/",
    "0 0 0",
    ]
    #出力ファイル名
    output="h2o_bec.ph.in"
    #ファイルの保存
    with open(output, mode='w') as f:
        f.write('\n'.join(lines))

# %%
#copy.shの作成
def make_copyfile():
    lines=[
    "#!/bin/sh",
    "number=0",
    "while test $number -le 14",
    "do",
    "      cp sample4.slurm ./water_$number/",
    "      number=`expr $number + 1`",
    "done",
    ]
    #出力ファイル名
    output="copy.sh"
    #ファイルの保存
    with open(output, mode='w') as f:
        f.write('\n'.join(lines))

# %%
# wan.shの作成
# ここで結晶構造も必要なので場合によって書き換えること！！
def make_wanfile(O,H1,H2):
        lines=[
            "# num_wann sould be equal to nbnd",
            "# default nbnd in insulater is electron num/2",
            "num_wann        = 4",
            "num_iter        = 100",
            " ",
            "translate_home_cell=true",
            " ",
            "guiding_centres = true",
            " ",
            "# level of verbosity of the output from 0 to 3(high)",
            "iprint          = 2",
            " ",
            "wannier_plot=.true.",
            "# wannier function output format",
            "wannier_plot_format = cube",
            "wannier_plot_mode = molecule",
            " ",
            " ",
            "begin atoms_cart",
            "ang",
            " O {0} {1} {2}".format(O[0], O[1], O[2]), 
            " H {0} {1} {2}".format(H1[0], H1[1], H1[2]), 
            " H {0} {1} {2}".format(H2[0], H2[1], H2[2]), 
            "end atoms_cart",
            " ",
            "begin projections",
            "random",
            "end projections",
            " ",
            "# ang or bohr",
            "begin unit_cell_cart",
            "bohr",
            "12.00000000000   0.00000000000000 0.00000000000000",
            "0.00000000000000 12.0000000000000 0.00000000000000",
            "0.00000000000000 0.00000000000000 12.0000000000000",
            "end unit_cell_cart",
            " ",
            "mp_grid    : 1 1 1",
            "gamma_only : true",
            " ",
            "begin kpoints",
            "0.0 0.0 0.0",
            "end kpoints",
        ]
        #出力ファイル名
        output="h2o_bec.win"
        #ファイルの保存
        with open(output, mode='w') as f:
            f.write('\n'.join(lines))

# %%
# pw2wanファイルの作成
def make_pw2wan():
    lines=[
    "&inputpp",
    "outdir         = './work/'",
   "prefix         = 'h2o_bec'",
   "seedname       = 'h2o_bec'",
   "spin_component = 'none'",
   "write_mmn      = .true.",
   "write_amn      = .true.",
   "write_unk      = .true.",
   "/",
    ]
    #出力ファイル名
    output="h2o_bec.pw2wan"
    #ファイルの保存
    with open(output, mode='w') as f:
        f.write('\n'.join(lines))

# %%
# スクリプトの実行用ファイル
#slurm.shの作成
def make_jobfile(SIZE):
    lines=[
    "#!/bin/sh",
    "number=0",
    " ",
    "# 現在のdirを取得",
    "CURRENT_DIR=$(pwd)",
    " ",
    "while test $number -le {0}".format(SIZE),
    "do",
    " ",
    "    #working dirへ移動",
    "    cd ${CURRENT_DIR}/water_$number/",
    " ",
    "    #jobファイルの実行",  # modify here
    "    sbatch sample4.slurm",
    " ",
    "    number=`expr $number + 1`",
    "done",
    ]
    #出力ファイル名
    output="job.sh"
    #ファイルの保存
    with open(output, mode='w') as f:
        f.write('\n'.join(lines))

# %%
#filenameファイルのディレクトリを移動する．
# shutil.copyfileはscrのファイルをcopyにコピーする．
def copyfile1(num,filename):
    import shutil
    copy = './water_{}'.format(str(num)) #移動先のdir
    shutil.move(filename,copy)

#water_10などのdirを作成
def make_dir(new_dir_path):
    import os
    import shutil
    if os.path.exists(new_dir_path)==True:
        shutil.rmtree(new_dir_path) # すでに存在すれば削除
    os.mkdir(new_dir_path)

# %%
# 実際にファイル群を作成する関数
def make_files(zahixyou,SIZE,NUM_MOLECULE):
    for step in np.arange(SIZE):
        print("ステップ：：", step)

        #water_stepのdir作成
        make_dir("water_{0}".format(step))
    
        #必要ファイル作成
        make_scffile(zahixyou, NUM_MOLECULE, step)
        make_phfile()
        make_wanfile(zahixyou, NUM_MOLECULE, step)
        make_pw2wanfile()
        make_scriptfile()
    
        #ファイル移動
        copyfile1(step,"h2o_bec.pw.in")
        copyfile1(step,"h2o_bec.pw2wan")
        copyfile1(step,"h2o_bec.ph.in")
        copyfile1(step,"h2o_bec.win")
        copyfile1(step,"script.sh")

    # 最後にjobファイルの作成
    make_jobfile(SIZE)

# %%
# 水の角度変化に対応した座標の計算
#
# 長さはdefaultで0.9693 ang.（relaxしたもの）
# 角度のdefalutは104.107度（relaxしたもの）
def angle_cordinate(angle, long):
    #
    print("angle = ", angle, "   [度]")
    print("long = ", long ,    "   Angstrom")
    # H2の座標を計算
    cord_O  =np.array([0.00, 0.00, 0.00])
    cord_H1=np.array([long, 0.00, 0.00])
    cord_H2=np.array([long*np.cos(angle*np.pi/180), long*np.sin(angle*np.pi/180), 0.00])
    #
    return cord_O, cord_H1, cord_H2

# %%
# 実際にファイル群を作成
#

## 長さのリストを作成
list=np.linspace(0.85,1.05,100)
print(list)
#
## long/angleの指定
#long=0.9693 
angle=104.107
#
counter=1
#
for long in list:
    print("ステップ：：", long)
    
    # 3つの座標の取得
    O, H1, H2=angle_cordinate(angle, long)
    
    #water_angleのdir作成
    make_dir("water_"+str(int(counter)))
    print("water_"+str(int(counter)))
    
    #pwファイル作成
    make_file(O,H1,H2)
    
    #pwファイル移動
    copyfile1(str(int(counter)),"h2o_bec.pw.in")
    
    #phファイル作成
    make_phfile()
    
    #phファイル移動
    copyfile1(str(int(counter)),"h2o_bec.ph.in")
    
    #wanファイル作成
    #make_wanfile(O,H1,H2)
    #wanファイル移動
    #copyfile3(step)
    #pw2wanファイル作成
    #make_pw2wan()
    
    # counterの更新
    counter+=1
    
    
# 最後にcopy,slurm,jobファイルの作成
make_copyfile()
#make_slurmfile()
make_copyfile()
# Out:
# [0.85       0.8520202  0.8540404  0.85606061 0.85808081 0.86010101
#  0.86212121 0.86414141 0.86616162 0.86818182 0.87020202 0.87222222
#  0.87424242 0.87626263 0.87828283 0.88030303 0.88232323 0.88434343
#  0.88636364 0.88838384 0.89040404 0.89242424 0.89444444 0.89646465
#  0.89848485 0.90050505 0.90252525 0.90454545 0.90656566 0.90858586
#  0.91060606 0.91262626 0.91464646 0.91666667 0.91868687 0.92070707
#  0.92272727 0.92474747 0.92676768 0.92878788 0.93080808 0.93282828
#  0.93484848 0.93686869 0.93888889 0.94090909 0.94292929 0.94494949
#  0.9469697  0.9489899  0.9510101  0.9530303  0.95505051 0.95707071
#  0.95909091 0.96111111 0.96313131 0.96515152 0.96717172 0.96919192
#  0.97121212 0.97323232 0.97525253 0.97727273 0.97929293 0.98131313
#  0.98333333 0.98535354 0.98737374 0.98939394 0.99141414 0.99343434
#  0.99545455 0.99747475 0.99949495 1.00151515 1.00353535 1.00555556
#  1.00757576 1.00959596 1.01161616 1.01363636 1.01565657 1.01767677
#  1.01969697 1.02171717 1.02373737 1.02575758 1.02777778 1.02979798
#  1.03181818 1.03383838 1.03585859 1.03787879 1.03989899 1.04191919
#  1.04393939 1.0459596  1.0479798  1.05      ]
# ステップ：： 0.85
# angle =  104.107    [度]
# long =  0.85    Angstrom
# water_1
# ステップ：： 0.852020202020202
# angle =  104.107    [度]
# long =  0.852020202020202    Angstrom
# water_2
# ステップ：： 0.854040404040404
# angle =  104.107    [度]
# long =  0.854040404040404    Angstrom
# water_3
# ステップ：： 0.8560606060606061
# angle =  104.107    [度]
# long =  0.8560606060606061    Angstrom
# water_4
# ステップ：： 0.8580808080808081
# angle =  104.107    [度]
# long =  0.8580808080808081    Angstrom
# water_5
# ステップ：： 0.86010101010101
# angle =  104.107    [度]
# long =  0.86010101010101    Angstrom
# water_6
# ステップ：： 0.8621212121212121
# angle =  104.107    [度]
# long =  0.8621212121212121    Angstrom
# water_7
# ステップ：： 0.8641414141414141
# angle =  104.107    [度]
# long =  0.8641414141414141    Angstrom
# water_8
# ステップ：： 0.8661616161616161
# angle =  104.107    [度]
# long =  0.8661616161616161    Angstrom
# water_9
# ステップ：： 0.8681818181818182
# angle =  104.107    [度]
# long =  0.8681818181818182    Angstrom
# water_10
# ステップ：： 0.8702020202020202
# angle =  104.107    [度]
# long =  0.8702020202020202    Angstrom
# water_11
# ステップ：： 0.8722222222222222
# angle =  104.107    [度]
# long =  0.8722222222222222    Angstrom
# water_12
# ステップ：： 0.8742424242424243
# angle =  104.107    [度]
# long =  0.8742424242424243    Angstrom
# water_13
# ステップ：： 0.8762626262626263
# angle =  104.107    [度]
# long =  0.8762626262626263    Angstrom
# water_14
# ステップ：： 0.8782828282828282
# angle =  104.107    [度]
# long =  0.8782828282828282    Angstrom
# water_15
# ステップ：： 0.8803030303030303
# angle =  104.107    [度]
# long =  0.8803030303030303    Angstrom
# water_16
# ステップ：： 0.8823232323232323
# angle =  104.107    [度]
# long =  0.8823232323232323    Angstrom
# water_17
# ステップ：： 0.8843434343434343
# angle =  104.107    [度]
# long =  0.8843434343434343    Angstrom
# water_18
# ステップ：： 0.8863636363636364
# angle =  104.107    [度]
# long =  0.8863636363636364    Angstrom
# water_19
# ステップ：： 0.8883838383838384
# angle =  104.107    [度]
# long =  0.8883838383838384    Angstrom
# water_20
# ステップ：： 0.8904040404040404
# angle =  104.107    [度]
# long =  0.8904040404040404    Angstrom
# water_21
# ステップ：： 0.8924242424242425
# angle =  104.107    [度]
# long =  0.8924242424242425    Angstrom
# water_22
# ステップ：： 0.8944444444444445
# angle =  104.107    [度]
# long =  0.8944444444444445    Angstrom
# water_23
# ステップ：： 0.8964646464646464
# angle =  104.107    [度]
# long =  0.8964646464646464    Angstrom
# water_24
# ステップ：： 0.8984848484848484
# angle =  104.107    [度]
# long =  0.8984848484848484    Angstrom
# water_25
# ステップ：： 0.9005050505050505
# angle =  104.107    [度]
# long =  0.9005050505050505    Angstrom
# water_26
# ステップ：： 0.9025252525252525
# angle =  104.107    [度]
# long =  0.9025252525252525    Angstrom
# water_27
# ステップ：： 0.9045454545454545
# angle =  104.107    [度]
# long =  0.9045454545454545    Angstrom
# water_28
# ステップ：： 0.9065656565656566
# angle =  104.107    [度]
# long =  0.9065656565656566    Angstrom
# water_29
# ステップ：： 0.9085858585858586
# angle =  104.107    [度]
# long =  0.9085858585858586    Angstrom
# water_30
# ステップ：： 0.9106060606060606
# angle =  104.107    [度]
# long =  0.9106060606060606    Angstrom
# water_31
# ステップ：： 0.9126262626262627
# angle =  104.107    [度]
# long =  0.9126262626262627    Angstrom
# water_32
# ステップ：： 0.9146464646464647
# angle =  104.107    [度]
# long =  0.9146464646464647    Angstrom
# water_33
# ステップ：： 0.9166666666666666
# angle =  104.107    [度]
# long =  0.9166666666666666    Angstrom
# water_34
# ステップ：： 0.9186868686868687
# angle =  104.107    [度]
# long =  0.9186868686868687    Angstrom
# water_35
# ステップ：： 0.9207070707070707
# angle =  104.107    [度]
# long =  0.9207070707070707    Angstrom
# water_36
# ステップ：： 0.9227272727272727
# angle =  104.107    [度]
# long =  0.9227272727272727    Angstrom
# water_37
# ステップ：： 0.9247474747474748
# angle =  104.107    [度]
# long =  0.9247474747474748    Angstrom
# water_38
# ステップ：： 0.9267676767676768
# angle =  104.107    [度]
# long =  0.9267676767676768    Angstrom
# water_39
# ステップ：： 0.9287878787878788
# angle =  104.107    [度]
# long =  0.9287878787878788    Angstrom
# water_40
# ステップ：： 0.9308080808080809
# angle =  104.107    [度]
# long =  0.9308080808080809    Angstrom
# water_41
# ステップ：： 0.9328282828282828
# angle =  104.107    [度]
# long =  0.9328282828282828    Angstrom
# water_42
# ステップ：： 0.9348484848484848
# angle =  104.107    [度]
# long =  0.9348484848484848    Angstrom
# water_43
# ステップ：： 0.9368686868686869
# angle =  104.107    [度]
# long =  0.9368686868686869    Angstrom
# water_44
# ステップ：： 0.9388888888888889
# angle =  104.107    [度]
# long =  0.9388888888888889    Angstrom
# water_45
# ステップ：： 0.9409090909090909
# angle =  104.107    [度]
# long =  0.9409090909090909    Angstrom
# water_46
# ステップ：： 0.942929292929293
# angle =  104.107    [度]
# long =  0.942929292929293    Angstrom
# water_47
# ステップ：： 0.944949494949495
# angle =  104.107    [度]
# long =  0.944949494949495    Angstrom
# water_48
# ステップ：： 0.946969696969697
# angle =  104.107    [度]
# long =  0.946969696969697    Angstrom
# water_49
# ステップ：： 0.948989898989899
# angle =  104.107    [度]
# long =  0.948989898989899    Angstrom
# water_50
# ステップ：： 0.9510101010101011
# angle =  104.107    [度]
# long =  0.9510101010101011    Angstrom
# water_51
# ステップ：： 0.953030303030303
# angle =  104.107    [度]
# long =  0.953030303030303    Angstrom
# water_52
# ステップ：： 0.955050505050505
# angle =  104.107    [度]
# long =  0.955050505050505    Angstrom
# water_53
# ステップ：： 0.9570707070707071
# angle =  104.107    [度]
# long =  0.9570707070707071    Angstrom
# water_54
# ステップ：： 0.9590909090909091
# angle =  104.107    [度]
# long =  0.9590909090909091    Angstrom
# water_55
# ステップ：： 0.9611111111111111
# angle =  104.107    [度]
# long =  0.9611111111111111    Angstrom
# water_56
# ステップ：： 0.9631313131313132
# angle =  104.107    [度]
# long =  0.9631313131313132    Angstrom
# water_57
# ステップ：： 0.9651515151515152
# angle =  104.107    [度]
# long =  0.9651515151515152    Angstrom
# water_58
# ステップ：： 0.9671717171717172
# angle =  104.107    [度]
# long =  0.9671717171717172    Angstrom
# water_59
# ステップ：： 0.9691919191919192
# angle =  104.107    [度]
# long =  0.9691919191919192    Angstrom
# water_60
# ステップ：： 0.9712121212121212
# angle =  104.107    [度]
# long =  0.9712121212121212    Angstrom
# water_61
# ステップ：： 0.9732323232323232
# angle =  104.107    [度]
# long =  0.9732323232323232    Angstrom
# water_62
# ステップ：： 0.9752525252525253
# angle =  104.107    [度]
# long =  0.9752525252525253    Angstrom
# water_63
# ステップ：： 0.9772727272727273
# angle =  104.107    [度]
# long =  0.9772727272727273    Angstrom
# water_64
# ステップ：： 0.9792929292929293
# angle =  104.107    [度]
# long =  0.9792929292929293    Angstrom
# water_65
# ステップ：： 0.9813131313131314
# angle =  104.107    [度]
# long =  0.9813131313131314    Angstrom
# water_66
# ステップ：： 0.9833333333333334
# angle =  104.107    [度]
# long =  0.9833333333333334    Angstrom
# water_67
# ステップ：： 0.9853535353535354
# angle =  104.107    [度]
# long =  0.9853535353535354    Angstrom
# water_68
# ステップ：： 0.9873737373737375
# angle =  104.107    [度]
# long =  0.9873737373737375    Angstrom
# water_69
# ステップ：： 0.9893939393939395
# angle =  104.107    [度]
# long =  0.9893939393939395    Angstrom
# water_70
# ステップ：： 0.9914141414141414
# angle =  104.107    [度]
# long =  0.9914141414141414    Angstrom
# water_71
# ステップ：： 0.9934343434343434
# angle =  104.107    [度]
# long =  0.9934343434343434    Angstrom
# water_72
# ステップ：： 0.9954545454545455
# angle =  104.107    [度]
# long =  0.9954545454545455    Angstrom
# water_73
# ステップ：： 0.9974747474747475
# angle =  104.107    [度]
# long =  0.9974747474747475    Angstrom
# water_74
# ステップ：： 0.9994949494949495
# angle =  104.107    [度]
# long =  0.9994949494949495    Angstrom
# water_75
# ステップ：： 1.0015151515151515
# angle =  104.107    [度]
# long =  1.0015151515151515    Angstrom
# water_76
# ステップ：： 1.0035353535353535
# angle =  104.107    [度]
# long =  1.0035353535353535    Angstrom
# water_77
# ステップ：： 1.0055555555555555
# angle =  104.107    [度]
# long =  1.0055555555555555    Angstrom
# water_78
# ステップ：： 1.0075757575757576
# angle =  104.107    [度]
# long =  1.0075757575757576    Angstrom
# water_79
# ステップ：： 1.0095959595959596
# angle =  104.107    [度]
# long =  1.0095959595959596    Angstrom
# water_80
# ステップ：： 1.0116161616161616
# angle =  104.107    [度]
# long =  1.0116161616161616    Angstrom
# water_81
# ステップ：： 1.0136363636363637
# angle =  104.107    [度]
# long =  1.0136363636363637    Angstrom
# water_82
# ステップ：： 1.0156565656565657
# angle =  104.107    [度]
# long =  1.0156565656565657    Angstrom
# water_83
# ステップ：： 1.0176767676767677
# angle =  104.107    [度]
# long =  1.0176767676767677    Angstrom
# water_84
# ステップ：： 1.0196969696969698
# angle =  104.107    [度]
# long =  1.0196969696969698    Angstrom
# water_85
# ステップ：： 1.0217171717171718
# angle =  104.107    [度]
# long =  1.0217171717171718    Angstrom
# water_86
# ステップ：： 1.0237373737373738
# angle =  104.107    [度]
# long =  1.0237373737373738    Angstrom
# water_87
# ステップ：： 1.0257575757575759
# angle =  104.107    [度]
# long =  1.0257575757575759    Angstrom
# water_88
# ステップ：： 1.027777777777778
# angle =  104.107    [度]
# long =  1.027777777777778    Angstrom
# water_89
# ステップ：： 1.02979797979798
# angle =  104.107    [度]
# long =  1.02979797979798    Angstrom
# water_90
# ステップ：： 1.031818181818182
# angle =  104.107    [度]
# long =  1.031818181818182    Angstrom
# water_91
# ステップ：： 1.033838383838384
# angle =  104.107    [度]
# long =  1.033838383838384    Angstrom
# water_92
# ステップ：： 1.0358585858585858
# angle =  104.107    [度]
# long =  1.0358585858585858    Angstrom
# water_93
# ステップ：： 1.0378787878787878
# angle =  104.107    [度]
# long =  1.0378787878787878    Angstrom
# water_94
# ステップ：： 1.0398989898989899
# angle =  104.107    [度]
# long =  1.0398989898989899    Angstrom
# water_95
# ステップ：： 1.041919191919192
# angle =  104.107    [度]
# long =  1.041919191919192    Angstrom
# water_96
# ステップ：： 1.043939393939394
# angle =  104.107    [度]
# long =  1.043939393939394    Angstrom
# water_97
# ステップ：： 1.045959595959596
# angle =  104.107    [度]
# long =  1.045959595959596    Angstrom
# water_98
# ステップ：： 1.047979797979798
# angle =  104.107    [度]
# long =  1.047979797979798    Angstrom
# water_99
# ステップ：： 1.05
# angle =  104.107    [度]
# long =  1.05    Angstrom
# water_100
